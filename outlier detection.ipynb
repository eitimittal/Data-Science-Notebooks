# %%
import pandas as pd
import numpy as np

# %%
#read data
initialdata=pd.read_csv("F:\\5thsem\\DA\\268833_611395_bundle_archive\\AB_NYC_2019.csv")

# %%
initialdata.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#checking for any null values 
initialdata['price'].isnull().any()
# Out:
# False

# %%
#add a column to get price per night
initialdata['pricepernight']=dt['price']/dt['minimum_nights']

# %%
#reviewing the data
initialdata.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bins=pd.qcut(initialdata['pricepernight'],20)
pd.value_counts(bins)
#analysed the lenggth of a bin vs its value count
# Out:
# (44.5, 50.0]       3598
# (6.167, 10.0]      2735
# (140.0, 200.0]     2711
# (15.0, 20.0]       2700
# (29.0, 33.333]     2622
# (-0.001, 3.333]    2509
# (38.5, 44.5]       2497
# (111.0, 140.0]     2494
# (55.5, 63.0]       2480
# (63.0, 72.5]       2459
# (81.5, 96.667]     2447
# (96.667, 111.0]    2443
# (10.0, 15.0]       2430
# (24.5, 29.0]       2421
# (3.333, 6.167]     2398
# (72.5, 81.5]       2389
# (33.333, 38.5]     2261
# (200.0, 8000.0]    2128
# (20.0, 24.5]       1931
# (50.0, 55.5]       1242
# Name: pricepernight, dtype: int64

# %%
fig=plt.figure(figsize=(10, 7))
plt.boxplot(initialdata['pricepernight'])
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(initialdata['pricepernight'])

# %%
initialdata.describe()
#noted initial mean and standard deviation
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
initialdata.sort_values(by=['pricepernight'])
# Out:
#              id                                               name    host_id  \
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# ...         ...                                                ...        ...
# 44034  33998396                   3000 sq ft daylight photo studio    3750764
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 45666  34895693                               Gem of east Flatbush  262534951
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 4377    2953058                                      Film Location    1177497
#
# ...

# %%
#Percentile Capping 
q1, q3= np.percentile(initialdata['pricepernight'],[10,90])

# %%
print(q1,q3)
# Out:
# 6.166666666666667 140.0

# %%
#Used in IQR METHOD
#iqr = q3-q1
#Lower_tail = q1 - 1.5 * iqr
#Upper_tail = q3 + 1.5 * iqr

# %%
#removing extreme values and storing the outlier free data in final data
finaldata=initialdata[(initialdata.pricepernight>q1) & (initialdata.pricepernight<q3)]

# %%
#compare the no of rows
initialdata.shape
# Out:
# (48895, 17)

# %%
finaldata.shape
# Out:
# (39011, 17)

# %%
#initial mean=70.17 std=157.62
#final mean=50.57 std=32.54
finaldata.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.901100e+04  3.901100e+04  39011.000000  39011.000000  39011.000000
# mean   1.887372e+07  6.543303e+07     40.727996    -73.950049    129.266643
# std    1.083146e+07  7.670227e+07      0.055753      0.047209    140.858187
# min    3.647000e+03  2.571000e+03     40.499790    -74.244420     10.000000
# 25%    9.515334e+06  7.630478e+06     40.688550    -73.981605     68.000000
# 50%    1.954707e+07  3.022311e+07     40.720850    -73.954000    100.000000
# 75%    2.862617e+07  1.042684e+08     40.763205    -73.933415    159.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    39011.000000       39011.000000       32021.000000
# mean         4.104509          25.467227           1.426053
# std          6.360290          46.414743           1.694869
# ...

# %%
fig=plt.figure(figsize=(15, 8))
plt.boxplot(finaldata['pricepernight'])
plt.show()
